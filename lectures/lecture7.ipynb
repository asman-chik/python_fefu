# %% [markdown]
# # Курс Python. Занятие 7. Введение в нейронные сети

# %% [markdown]
# ### Предисловие
#
# **Эта лекция в виде слайдов:**  https://nbviewer.jupyter.org/format/slides/github/pikvic/python_fefu/blob/master/lectures/lecture7.ipynb#/
#
# Материалы для изучения (список не мой, но посыл верный).
#
# Книги
# 1. [Любая книга, которую вы найдете](https://scholar.google.ru/scholar?hl=ru&as_sdt=0%2C5&q=%D0%BD%D0%B5%D0%B9%D1%80%D0%BE%D0%BD%D0%BD%D1%8B%D0%B5+%D1%81%D0%B5%D1%82%D0%B8&btnG=).
# 2. [Хайкин С. Нейронные сети: полный курс, 2-е издание. – Издательский дом Вильямс, 2008.](https://www.google.com/books?hl=ru&lr=&id=LPMr0iA0muwC&oi=fnd&pg=PA22&ots=4d1Hh4_NA7&sig=WhhjlewVu5Jc2px6kNndeLMXB68)
# 3. [Николенко С. И., Кадурин А. А., Архангельская Е. О. Глубокое обучение СПб: Питер, 2019.](https://www.piter.com/product/glubokoe-obuchenie)
# 4. [Гудфеллоу Я., Иошуа Б., Курвилль А. Глубокое обучение. – Litres, 2017](https://www.google.com/books?hl=ru&lr=&id=741EDwAAQBAJ&oi=fnd&pg=PA14&dq=related:1llkUhAywd8J:scholar.google.com/&ots=3bcjOiPuxy&sig=7K-nf3JD8Hjzo42xCOkoQKMgkAI). (Доступна онлайн [Исходная (английская) версия](http://www.deeplearningbook.org/).)
#
# Курсы/Видеолекции
# 1. Курс "Convolutional Neural Networks for Visual Recognition" Стендфордского университета ([Страница курса](http://cs231n.stanford.edu/), [Видеолекции на Youtube](https://www.youtube.com/playlist?list=PLkt2uSq6rBVctENoVBg1TpCC7OQi31AlC))
#
# 2. Курс "Машинное обучение" Школы анализа данных, Яндекс ([Видеолекции](https://yandexdataschool.ru/edu-process/courses/machine-learning))
#
# 3. Курс "Learning from data" Калифорнийского технологического института ([Страница курса](https://work.caltech.edu/telecourse.html), [Видеолекции на Youtube](https://www.youtube.com/playlist?list=PLD63A284B7615313A))

# %% [markdown]
# ## Часть 1. Термины и постановка задачи

# %% [markdown]
# ### Машинное обучение
# Машинное обучение - класс методов искусственного интеллекта, характерной чертой которых является не прямое решение задачи, а обучение в процессе применения решений множества сходных задач.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Виды машинного обучения и решаемых их задач
# - Обучение с учителем (Supervised Machine Learning)
# - Обучение без учителя (Unsupervised Machine Learning)
# - Обучение с подкреплением (Reinforcement Machine Learning)
# ![](https://i.imgur.com/mZdJLdg.png)

# %% [markdown]
# ![](https://i.pinimg.com/originals/4c/67/31/4c6731306d2db82a3305122b5abc6824.jpg)

# %% [markdown]
# ![](https://www.novatec-gmbh.de/wp-content/uploads/1_mPGk9WTNNvp3i4-9JFgD3w.png)

# %% [markdown]
# Обучение с учителем: классификация vs регрессия
# ![](https://cdn-images-1.medium.com/max/1600/0*WE3Sz--1NUEWBmUR.)

# %% [markdown]
# Обучение с учителем для изображений
# ![](https://cdn-images-1.medium.com/max/1000/1*nR5QCdmqUnvU2JFBu2Xa-Q.png)

# %% [markdown]
# ### Нейрон и математическая модель нейрона
# Нейрон - электрически возбудимая клетка, которая обрабатывает, хранит и передает информацию с помощью электрических и химических сигналов. Нейроны могут соединяться один с другим, формируя биологические нейронные сети.
# ![Нейрон](http://elementy.ru/images/news/neuron_structure_600.gif)

# %% [markdown]
# Искусственный нейрон - математическая модель биологического нейрона.
# ![](https://cdn-images-1.medium.com/max/1000/0*LaXMcr3mL9jQ183s)

# %% [markdown]
# ### Входные, выходные данные, входы, веса, функция активации, выходы
# Входные данные - массив M измерений, каждое из которых состоит из N признаков.
# <br><br>
# Выходные данные - массив из M значений, соответствующих входным данным, каждое из которых может состоять из K признаков.
# ![](https://cdn-images-1.medium.com/max/1000/1*WlCd6kgxqb2yQpcutLhYwQ.png)

# %% [markdown]
# Входы нейрона - один элемент из входных данных, количество входов равно количеству признаков, составляющих элемент.
# <br><br>
# Веса нейрона - вклад каждого входа в результирующую сумму всех входов нейрона.
# <br><br>
# Выход нейрона - результат суммирования произведений входов с весами.
# <br><br>
# Функция активации - некая нелинейная функция, преобразующая выход нейрона.
# ![](https://cdn-images-1.medium.com/max/1000/1*n6sJ4yZQzwKL9wnF5wnVNg.png)

# %% [markdown]
# ### Нейронные сети, слои, нелинейность, параметры сети
# Нейронная сеть - система соединенных и взаимодействующих между собой искусственных нейронов. Нейроны объединяются в слои.
# ![](https://cdn-images-1.medium.com/max/1000/1*eEKb2RxREV6-MtLz2DNWFQ.gif)

# %% [markdown]
# Входной слой - слой нейронов, выходы которых являются значениями входных данных. Количество нейронов в слое соответствует количеству признаков во входных данных.
# <br><br>
# Выходной слой - слой нейронов, выходы которых являются значением выходов для соответствующих входных данных. Количество нейронов соответствует количеству признаков в выходах.
# <br><br>
# Скрытые слои - слои нейронов, входы которых - выходы с предыдущих слоёв, а выходы - входы для следующих.
# <br><br>
# Параметры нейросети - все веса сети.
# <br><br>
# Гиперпараметры нейросети - количество слоёв, количество нейронов в слоях и т.д.

# %% [markdown]
# ![](https://www.researchgate.net/publication/299474560/figure/fig6/AS:349583008911366@1460358492284/An-example-of-a-deep-neural-network-with-two-hidden-layers-The-first-layer-is-the-input.png)

# %% [markdown]
# ![](https://machinethink.net/images/vggnet-convolutional-neural-network-iphone/MatrixMultiplication.png)

# %% [markdown]
# ### Обучение нейросетей, целевая функция, прямой и обратный проходы
# Прямой проход - расчёт значений выходного слоя на основе значений входного слоя через все скрытые слои.
# <br>
# <br>
# Целевая функция (функция потерь) - функция от обучающих выходных значений y0 и выходных значений нейросети y. Например, среднеквадратичное отклонение.
# <br>
# <br>
# Обучение нейросети - процесс подбора параметров (весов) нейросети с целью миницизации функции потерь.
# <br>
# <br>
# Обратный проход - дифферинцирование функции потерь по всем параметрам нейросети.

# %% [markdown]
# ## Часть 2. Простейший пример нейронной сети

# %% [markdown]
# ### Постановка задачи линейной регрессии
# Для начала попробуем решить простую задачу: подобрать для функции y = kx + b параметры k и b при известном наборе значений x0 и y0.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt


np.random.seed(42)
n, k, b = 200, 2.5, 6
x0 = np.linspace(-2.0, 2.0, n)
y0 = x0 * k + b + np.random.normal(loc=0, scale=0.7, size=n)

fig, ax = plt.subplots(figsize=(8,3))
ax.scatter(x0, y0, marker='x'), ax.set_xlabel('x0'), ax.set_ylabel('y0');

# %% [markdown]
# ### Модель и прямой проход
# В качестве модели для решения задачи возьмём нейронную сеть из 1 входного и 1 выходного нейрона. Без функции активации, потому как нам нужна активация выходного нейрона в чистом виде.
#
# ![](https://i.stack.imgur.com/bI2Tm.gif)
# ![](https://i.stack.imgur.com/oapHD.gif)
# Тогда прямой проход (предсказание y по входам x) будет следующим:
# ![](https://cdn-images-1.medium.com/max/1000/0*NOG_xxqN9f3-dKws.png)

# %% [markdown]
# ### Функция потерь
# В качестве функции потерь возьмём среднеквадратичную ошибку (Mean Square Error):
# ![](https://cdn-images-1.medium.com/max/1000/0*3tUgqNjtX102ruKT.png)
# - i — номер точки из x0
# - ŷ — модельное значение
# - y — реальное значение
# - m — количество точек во входном наборе данных
# <br><br>
# Можно переписать в виде:
# ![](https://cdn-images-1.medium.com/max/1000/0*3boprC82I9Aq2DS4.png)

# %%
def mse(y_pred, y_real):
    samples_num = y_real.shape[0]
    mae_error = (1.0 / (2*samples_num)) * np.sum((y_pred - y_real)**2)
    return mae_error

# %% [markdown]
# ### Обратный проход: обратное распространение ошибки и градиентный спуск
# Для корректировки параметров модели используется так называемый метод обратного распространения ошибки (backpropagation). Он базируется на методе градиентного спуска (gradient descent).
# ![](https://cdn-images-1.medium.com/max/1000/1*iWRgqnhWm5CBt-0Pi6hzbg.gif)

# %% [markdown]
# Ещё раз приведём формулы расчёта ошибки (функции потерь) и градиенты для параметров w и b:
# ![](https://cdn-images-1.medium.com/max/1000/0*3boprC82I9Aq2DS4.png)
# ![](https://cdn-images-1.medium.com/max/1000/0*7Hv7sFAy5xOPdIQN.png)
# ![](https://cdn-images-1.medium.com/max/1000/0*2f2pJmQ3fQHrZ0GV.png)
# Обновление значений параметров будем проводить по следующим формулам (где α - "скорость обучения"):
# ![](https://cdn-images-1.medium.com/max/1000/0*wOYOnCSQ9EJccJhy.png)

# %%
# Зададим начальные параметры
w, b = 0, 0
iterations = 1000
learning_rate = 0.01
m = x0.shape[0]
errors = []

# Проведём обучение модели
for iteration in range(iterations):
    y = w * x0 + b
    dw = (1 / m) * np.sum((y - y0) * x0)
    db = (1 / m) * np.sum(y - y0)
    w = w - learning_rate * dw
    b = b - learning_rate * db
    errors.append(mse(y, y0))

# Отобразим результаты
fig, ax = plt.subplots(1, 2, figsize=(8, 2))
fig.tight_layout()
ax[0].plot(range(iterations), errors)
ax[0].set_xlabel('Iteration'), ax[0].set_ylabel('Error')
ax[1].scatter(x0, y0, marker='x')
ax[1].plot(x0, y, color='r', linewidth=3)
ax[1].set_xlabel('x0'), ax[1].set_ylabel('y0');

# %% [markdown]
# Анимация подбора линии под набор точек
# ![](https://eli.thegreenplace.net/images/2016/regressionfit.gif)

# %% [markdown]
# ## Часть 3. Фреймворки и нормальные нейронные сети
# Фреймворки глубокого обучения служат для облегчения построения нейронных сетей различных архитектур, работы с данными, обучением нейросетей на графических процессорах и кластерах.
# <br><br>
# Мы будем работать с фреймворком PyTorch. Чтобы его установить с поддержкой только CPU (на ноутбуке другое не имеет смысла), нужно запустить следующую команду в консоли: `conda install pytorch-cpu torchvision-cpu -c pytorch`
# ![](https://cdn-images-1.medium.com/freeze/max/1000/1*7C46N8tlMQg28Y631HUZDQ.jpeg?q=20)

# %% [markdown]
# ### Линейная регрессия на PyTorch

# %%
# Импорт необходимых библиотек
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt

# Зададим те же самые входные данные
np.random.seed(42)
n, k, b = 200, 2.5, 6
x_train = np.linspace(-2.0, 2.0, n, dtype=np.float32)
y_train = x_train * k + b + np.random.normal(loc=0, scale=0.7, size=n)

# Гипер-параметры модели
input_size = 1
output_size = 1
num_epochs = 2000
learning_rate = 0.001

# Зададим нейросеть, используя специальный класс Linear, который реализует полносвязный слой
model = nn.Linear(input_size, output_size)

# Зададим функцияю потерь с помощью класса MSELoss и метод оптимизации - стохастический градиентный спуск
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
# Конвертируем массивы numpy в тензоры - многомерные массивы PyTorch
inputs = torch.from_numpy(x_train.reshape(n,1))
targets = torch.from_numpy(y_train.reshape(n,1).astype(np.float32))
errors = []

# Обучим модель
for epoch in range(num_epochs):
    # Прямой проход
    outputs = model(inputs)
    loss = criterion(outputs, targets)
    # Обратный проход и оптимизация. Обязательно обнулить градиенты!
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    errors.append(loss.item())
    
# Нарисуем графики
predicted = model(inputs)
fig, ax = plt.subplots(1,2,figsize=(8,3))
ax[0].plot(range(num_epochs), errors, label='Error')
ax[1].plot(x_train, y_train, 'ro', label='Original data')
ax[1].plot(x_train, predicted.detach().numpy(), label='Fitted line')
ax[0].legend(), ax[1].legend();

# %% [markdown]
# ### Распознавание рукописных цифр: набор данных MNIST
# База данных MNIST (сокращение от «Modified National Institute of Standards and Technology») — объёмная база данных образцов рукописного написания цифр.
# ![](https://cdn-images-1.medium.com/max/1000/1*_91Ir1B68lDv_8kSRHa9bg.jpeg)

# %% [markdown]
# Идея архитектуры сети: изображения размером 28x28 = 784 пикселя, поэтому пусть у сети будет 784 входа.
# ![](https://cdn-images-1.medium.com/max/1000/1*wPvGyzWJRHO-yxbI57p2zg.png)

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms

# Гипер параметры
input_size = 784
hidden_size = 500
num_classes = 10
num_epochs = 5
batch_size = 100
learning_rate = 0.001

# Выбор устройства, на котором проводить расчёты
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Загрузим встроенный в PyTorch MNIST dataset 
train_dataset = torchvision.datasets.MNIST(root='data', train=True, transform=transforms.ToTensor(), download=True)
test_dataset = torchvision.datasets.MNIST(root='data', train=False, transform=transforms.ToTensor())

# Создадим специальный класс DataLoader, который будет подавать изображения порциями по batch_size
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Зададим структуру нейронной сети с помощью класса, наследованного от nn.Module
class NeuralNet(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(NeuralNet, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size) 
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, num_classes)  
    
    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out

model = NeuralNet(input_size, hidden_size, num_classes).to(device)

# Зададим функцию потерь и метод оптимизации
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)  

# Напечатаем структуру модели
print(model)
# Out:
# NeuralNet(
#   (fc1): Linear(in_features=784, out_features=500, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=500, out_features=10, bias=True)
# )

# %%
# Обучим модель
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):  
        # Представим изображения в виде вектора длиной 784
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        
        # Прямой проход
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Обратный проход и оптимизация
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Печатаем информацию каждые 100 итераций
        if (i+1) % 300 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
# Out:
# Epoch [1/5], Step [300/600], Loss: 0.2376
# Epoch [1/5], Step [600/600], Loss: 0.1055
# Epoch [2/5], Step [300/600], Loss: 0.0394
# Epoch [2/5], Step [600/600], Loss: 0.0566
# Epoch [3/5], Step [300/600], Loss: 0.0724
# Epoch [3/5], Step [600/600], Loss: 0.0484
# Epoch [4/5], Step [300/600], Loss: 0.0476
# Epoch [4/5], Step [600/600], Loss: 0.0300
# Epoch [5/5], Step [300/600], Loss: 0.0043
# Epoch [5/5], Step [600/600], Loss: 0.0394

# %%
# Тестируем модель, для этого говорим PyTorch не считать градиенты
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.reshape(-1, 28*28).to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
    print('Accuracy of the network on the 10000 test images: {} %'.format(100 * correct / total))
# Out:
# Accuracy of the network on the 10000 test images: 98.02 %

# %%
# Посмотрим пример неверно определённых цифр
wrong = images[predicted != labels]
fig, ax = plt.subplots(1, 1)
array = wrong[0].reshape(28, 28).to('cpu').numpy()
ax.imshow(array, cmap='gray')
ax.set_title(f'Predicted: {predicted[predicted != labels][0]}\nGround Truth: {labels[predicted != labels][0]}');
